# %% [markdown]
# <img src="https://datern.co.uk/wp-content/uploads/2020/11/Datern_logo.png" width="300">
#
# # Short tutorial for using APIs and working with JSON
#
# ![Logo Image](https://datern.co.uk/wp-content/uploads/2020/07/qtq80-GTZMIV-e1596804686631.jpeg)

# %%
import requests

# %% [markdown]
# There a list of public APIs to choose from here: https://github.com/public-apis/public-apis
#
# https://github.com/public-apis/public-apis#cryptocurrency
#
# For starting off, I'd recommend picking an api that doesn't require Auth Key, as this simplifies things greatly.
#
# For this short tutorial, I picked https://docs.coincap.io/ from the list of the public apis to get the real time prices of cryptocurrencies.

# %%
url = 'http://api.coincap.io/v2/assets'

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json'
}

# %% [markdown]
# # Make an API GET request

# %%
response = requests.get(url, headers = headers, data = {})
json_data = response.json()

# %%
json_data
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19078587.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '398840882775.6141546651650592',
#    'volumeUsd24Hr': '8132119427.2077848785205178',
#    'priceUsd': '20905.1583733960043616',
#    'changePercent24Hr': '-1.4952541251437787',
#    'vwap24Hr': '21163.1381020440820338',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '121322281.4365000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '146631488334.5789135782712201',
#    'volumeUsd24Hr': '5898724835.1791259516324261',
#    'priceUsd': '1208.6113663410272691',
#    'changePercent24Hr': '-0.8565139825259928',
#    'vwap24Hr': '1215.0473532862029057',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '66867260244.0860440000000000',
#    'maxSupply': None,
#    'marketCapUsd': '66895654098.8927100117104719',
#    'volumeUsd24Hr': '17128300091.8898529120802505',
#    'priceUsd': '1.0004246301508843',
#    'changePercent24Hr': '-0.0705247422837273',
#    'vwap24Hr': '0.9994957688895139',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'usd-coin',
#    'rank': '4',
#    'symbol': 'USDC',
#    'name': 'USD Coin',
#    'supply': '55802605112.7154800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '55868899776.7498710390365301',
#    'volumeUsd24Hr': '1375201918.1372234509149325',
#    'priceUsd': '1.0011880209517187',
#    'changePercent24Hr': '-0.0997586233506359',
#    'vwap24Hr': '1.0009817067850516',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'binance-coin',
#    'rank': '5',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '39438335396.2383666251474328',
#    'volumeUsd24Hr': '271344221.0356975630448304',
#    'priceUsd': '236.4392323980789786',
#    'changePercent24Hr': '-0.2741358247811622',
#    'vwap24Hr': '236.1319732343868865',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'binance-usd',
#    'rank': '6',
#    'symbol': 'BUSD',
#    'name': 'Binance USD',
#    'supply': '17389381277.5592540000000000',
#    'maxSupply': None,
#    'marketCapUsd': '17415294450.5327226605360859',
#    'volumeUsd24Hr': '982581464.6117436920737541',
#    'priceUsd': '1.0014901722240635',
#    'changePercent24Hr': '-0.0545354423626884',
#    'vwap24Hr': '1.0011615576331034',
#    'explorer': 'https://etherscan.io/token/0x4Fabb145d64652a948d72533023f6E7A623C7C53'},
#   {'id': 'cardano',
#    'rank': '7',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '33752565071.2880000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '16488622061.5588251529826998',
#    'volumeUsd24Hr': '283279234.5258979977533201',
#    'priceUsd': '0.4885146366426846',
#    'changePercent24Hr': '-2.0607748593595996',
#    'vwap24Hr': '0.4963086908899923',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'xrp',
#    'rank': '8',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '16188395567.0982285106118400',
#    'volumeUsd24Hr': '452459490.4925911719329976',
#    'priceUsd': '0.3565409513647560',
#    'changePercent24Hr': '-1.5226711968879375',
#    'vwap24Hr': '0.3606709967931810',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'solana',
#    'rank': '9',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '342768321.9453497500000000',
#    'maxSupply': None,
#    'marketCapUsd': '13379396047.3435972934266287',
#    'volumeUsd24Hr': '321798894.2968164644421596',
#    'priceUsd': '39.0333504899463249',
#    'changePercent24Hr': '-2.5110255207387505',
#    'vwap24Hr': '39.7953893475530214',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'dogecoin',
#    'rank': '10',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '132670764299.8940900000000000',
#    'maxSupply': None,
#    'marketCapUsd': '9657544280.6080963324565224',
#    'volumeUsd24Hr': '481069811.9067838547953302',
#    'priceUsd': '0.0727933115601702',
#    'changePercent24Hr': '-0.1506509583725058',
#    'vwap24Hr': '0.0749880297540881',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'polkadot',
#    'rank': '11',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1126120007.3790600000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8884339658.7874126746888196',
#    'volumeUsd24Hr': '146960338.6086977708812019',
#    'priceUsd': '7.8893364832979837',
#    'changePercent24Hr': '-1.1901322775314858',
#    'vwap24Hr': '7.9908545478380704',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'terra-luna',
#    'rank': '12',
#    'symbol': 'LUNA',
#    'name': 'Terra',
#    'supply': '3453685944.3708580000000000',
#    'maxSupply': None,
#    'marketCapUsd': '7724589964.4246100791851305',
#    'volumeUsd24Hr': '158949220.8244727135238385',
#    'priceUsd': '2.2366220000445822',
#    'changePercent24Hr': '10.4860354747754660',
#    'vwap24Hr': '2.2443072968503594',
#    'explorer': 'https://finder.terra.money/'},
#   {'id': 'multi-collateral-dai',
#    'rank': '13',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '6766268428.6337760000000000',
#    'maxSupply': None,
#    'marketCapUsd': '6772538118.2473462721361320',
#    'volumeUsd24Hr': '107899320.2467110467027746',
#    'priceUsd': '1.0009266096489814',
#    'changePercent24Hr': '-0.0750837121520569',
#    'vwap24Hr': '1.0003706720683023',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'tron',
#    'rank': '14',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '92497237633.7046800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '6323212637.0927535130734092',
#    'volumeUsd24Hr': '294349388.7943942270797565',
#    'priceUsd': '0.0683610970322498',
#    'changePercent24Hr': '6.3539102185500122',
#    'vwap24Hr': '0.0676001294452885',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'shiba-inu',
#    'rank': '15',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '549063278876301.9400000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '6090486545.6455495370756172',
#    'volumeUsd24Hr': '352022307.3556484451241131',
#    'priceUsd': '0.0000110925038697',
#    'changePercent24Hr': '-2.3669416014931573',
#    'vwap24Hr': '0.0000113054596607',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'avalanche',
#    'rank': '16',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '281933998.9472421400000000',
#    'maxSupply': '720000000.0000000000000000',
#    'marketCapUsd': '5641179135.2492640000757919',
#    'volumeUsd24Hr': '195263643.8714825735568515',
#    'priceUsd': '20.0088643310624231',
#    'changePercent24Hr': '-1.0572414377575350',
#    'vwap24Hr': '20.2913413103285092',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '17',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '265028.7200218600000000',
#    'maxSupply': None,
#    'marketCapUsd': '5544127920.4785487320468810',
#    'volumeUsd24Hr': '115935488.2155793374472196',
#    'priceUsd': '20918.9702912999770043',
#    'changePercent24Hr': '-1.4099828559652484',
#    'vwap24Hr': '21202.4088301764934358',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'unus-sed-leo',
#    'rank': '18',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '953954130.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5529918938.2395577296367740',
#    'volumeUsd24Hr': '5500358.0928955849508633',
#    'priceUsd': '5.7968394541565198',
#    'changePercent24Hr': '-1.7824797095230610',
#    'vwap24Hr': '5.8894170277101895',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'polygon',
#    'rank': '19',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '8001489374.6200000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '4310298635.1381107336141496',
#    'volumeUsd24Hr': '331494048.4367126750447208',
#    'priceUsd': '0.5386870410413826',
#    'changePercent24Hr': '-6.8872470649450839',
#    'vwap24Hr': '0.5664554638788104',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'uniswap',
#    'rank': '20',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '734133449.9999107000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '3981764669.2323546063387280',
#    'volumeUsd24Hr': '78729056.4619663800108007',
#    'priceUsd': '5.4237614009181014',
#    'changePercent24Hr': '-3.7825102171377770',
#    'vwap24Hr': '5.6920551116927320',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'litecoin',
#    'rank': '21',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '70595893.7779146400000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '3979523931.4967361888832128',
#    'volumeUsd24Hr': '142725325.9807099784558198',
#    'priceUsd': '56.3704731045093501',
#    'changePercent24Hr': '-2.4585384146689275',
#    'vwap24Hr': '57.2679220236063382',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'ftx-token',
#    'rank': '22',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '135473350.2187437400000000',
#    'maxSupply': '352170015.0000000000000000',
#    'marketCapUsd': '3680986811.1466177333738712',
#    'volumeUsd24Hr': '20030429.2148874948743453',
#    'priceUsd': '27.1712983048183744',
#    'changePercent24Hr': '-1.7255169917557140',
#    'vwap24Hr': '27.4542369250203731',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'crypto-com-coin',
#    'rank': '23',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '3168398436.5915447919565968',
#    'volumeUsd24Hr': '12985750.9916558878153680',
#    'priceUsd': '0.1254164873288604',
#    'changePercent24Hr': '-1.0551404939720743',
#    'vwap24Hr': '0.1254736298549744',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'chainlink',
#    'rank': '24',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '467099970.5305637000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '3098023639.2669091132502689',
#    'volumeUsd24Hr': '162806235.4684791951185845',
#    'priceUsd': '6.6324637866021798',
#    'changePercent24Hr': '-4.1187030438899551',
#    'vwap24Hr': '6.8019133002978647',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'stellar',
#    'rank': '25',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '25026077606.2335320000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '2983284907.0211678197628745',
#    'volumeUsd24Hr': '42651727.1988466036040734',
#    'priceUsd': '0.1192070508995020',
#    'changePercent24Hr': '-2.7646579798842202',
#    'vwap24Hr': '0.1213269019490576',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'near-protocol',
#    'rank': '26',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '722062157.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '2726474075.6425258883057403',
#    'volumeUsd24Hr': '103959303.0193711140062307',
#    'priceUsd': '3.7759548111071079',
#    'changePercent24Hr': '-3.0941622000245126',
#    'vwap24Hr': '3.8673043228248510',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'algorand',
#    'rank': '27',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '6899230244.9403290000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '2300624910.7370166476804584',
#    'volumeUsd24Hr': '33826536.2731231082305250',
#    'priceUsd': '0.3334611005951309',
#    'changePercent24Hr': '-1.4024231860802283',
#    'vwap24Hr': '0.3366679404036719',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'ethereum-classic',
#    'rank': '28',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '135494978.8101867400000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '2258798950.5720478828244473',
#    'volumeUsd24Hr': '109433687.8823080973646406',
#    'priceUsd': '16.6707207190044417',
#    'changePercent24Hr': '2.9531585211996723',
#    'vwap24Hr': '17.0698004463702682',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'monero',
#    'rank': '29',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18140208.7792179500000000',
#    'maxSupply': None,
#    'marketCapUsd': '2234397803.5202832979323091',
#    'volumeUsd24Hr': '42756908.6151852628938646',
#    'priceUsd': '123.1737644651635228',
#    'changePercent24Hr': '-4.8817614203554888',
#    'vwap24Hr': '126.9260011336512745',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'bitcoin-bep2',
#    'rank': '30',
#    'symbol': 'BTCB',
#    'name': 'Bitcoin BEP2',
#    'supply': '105171.4470378700000000',
#    'maxSupply': None,
#    'marketCapUsd': '2196648390.1518615358408296',
#    'volumeUsd24Hr': '610375882.6562772636788955',
#    'priceUsd': '20886.3570105762184279',
#    'changePercent24Hr': '-1.4412623356537530',
#    'vwap24Hr': '21083.2877080745093413',
#    'explorer': 'https://explorer.binance.org/asset/BTCB-1DE'},
#   {'id': 'bitcoin-cash',
#    'rank': '31',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19102050.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '2144783179.5340643758414800',
#    'volumeUsd24Hr': '82829955.4136243803267138',
#    'priceUsd': '112.2802620417214056',
#    'changePercent24Hr': '-2.4011992984745318',
#    'vwap24Hr': '114.0742894626382896',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'cosmos',
#    'rank': '32',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2013831424.1343637595055062',
#    'volumeUsd24Hr': '94416593.7070818880763023',
#    'priceUsd': '8.1054758643836662',
#    'changePercent24Hr': '-3.0468915398194427',
#    'vwap24Hr': '8.2761762069466244',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'vechain',
#    'rank': '33',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '72511146418.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '1813107115.4042882858915296',
#    'volumeUsd24Hr': '52751876.8826555434821162',
#    'priceUsd': '0.0250045297167472',
#    'changePercent24Hr': '0.3215947105325332',
#    'vwap24Hr': '0.0248426054857313',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'decentraland',
#    'rank': '34',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1849220340.8482091000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1762916687.4774737197849959',
#    'volumeUsd24Hr': '97479834.1835197888956284',
#    'priceUsd': '0.9533297079507847',
#    'changePercent24Hr': '-0.7312433861379969',
#    'vwap24Hr': '0.9571217332470139',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'flow',
#    'rank': '35',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1036200000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1757326262.5351172447400000',
#    'volumeUsd24Hr': '22791969.4524103787129312',
#    'priceUsd': '1.6959334708889377',
#    'changePercent24Hr': '1.2602378670660629',
#    'vwap24Hr': '1.6881903339008992',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'the-sandbox',
#    'rank': '36',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '1258626081.2233226000000000',
#    'maxSupply': '3000000000.0000000000000000',
#    'marketCapUsd': '1493129935.7422973024607168',
#    'volumeUsd24Hr': '132371388.1389972780071521',
#    'priceUsd': '1.1863173328579434',
#    'changePercent24Hr': '-3.0663645412965377',
#    'vwap24Hr': '1.2117886811073041',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'internet-computer',
#    'rank': '37',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '241743240.2053223300000000',
#    'maxSupply': None,
#    'marketCapUsd': '1411173803.7590738033951790',
#    'volumeUsd24Hr': '37264292.5267591611145944',
#    'priceUsd': '5.8374902336897061',
#    'changePercent24Hr': '-1.2099978398311509',
#    'vwap24Hr': '5.9534628711387153',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'tezos',
#    'rank': '38',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '899605145.9830110000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1383234845.1042601986000235',
#    'volumeUsd24Hr': '32954090.6523035579666220',
#    'priceUsd': '1.5376021927851250',
#    'changePercent24Hr': '3.2340466569448148',
#    'vwap24Hr': '1.5143155786484577',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'theta',
#    'rank': '39',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '1348691691.1390895000000000',
#    'volumeUsd24Hr': '48798294.0331460580826061',
#    'priceUsd': '1.3486916911390895',
#    'changePercent24Hr': '-2.5120640953995032',
#    'vwap24Hr': '1.3618544010255232',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'axie-infinity',
#    'rank': '40',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '82093077.4265994100000000',
#    'maxSupply': '270000000.0000000000000000',
#    'marketCapUsd': '1318983348.2159146539051989',
#    'volumeUsd24Hr': '40380563.6901430038635734',
#    'priceUsd': '16.0669253676747160',
#    'changePercent24Hr': '-3.5613758965710211',
#    'vwap24Hr': '16.3818957350514674',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'filecoin',
#    'rank': '41',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '224373186.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1304964050.3804946563555382',
#    'volumeUsd24Hr': '68993841.8002169451077778',
#    'priceUsd': '5.8160427885553787',
#    'changePercent24Hr': '-2.4811025567539558',
#    'vwap24Hr': '5.9068909361698858',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'helium',
#    'rank': '42',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '120609573.2155817000000000',
#    'maxSupply': '223000000.0000000000000000',
#    'marketCapUsd': '1295355204.2368788907727282',
#    'volumeUsd24Hr': '8152219.2861862502231557',
#    'priceUsd': '10.7400695459017705',
#    'changePercent24Hr': '-1.7984999850669593',
#    'vwap24Hr': '10.8154559174886922',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'elrond-egld',
#    'rank': '43',
#    'symbol': 'EGLD',
#    'name': 'Elrond',
#    'supply': '22475931.0858792600000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '1291225014.7649191950526601',
#    'volumeUsd24Hr': '28233100.9614400766322510',
#    'priceUsd': '57.4492335748504268',
#    'changePercent24Hr': '-0.4421647486318754',
#    'vwap24Hr': '56.9605581306097069',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'trueusd',
#    'rank': '44',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '1198684591.8628270000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1200294976.4001453719271837',
#    'volumeUsd24Hr': '35278681.3291453781778323',
#    'priceUsd': '1.0013434597793701',
#    'changePercent24Hr': '-0.0139919727353770',
#    'vwap24Hr': '1.0011167336691554',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'bitcoin-sv',
#    'rank': '45',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19084882.8942390500000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1154991532.1084283287278367',
#    'volumeUsd24Hr': '13780246.0353586700044010',
#    'priceUsd': '60.5186596380464719',
#    'changePercent24Hr': '-3.1126493353091997',
#    'vwap24Hr': '61.3528194230916586',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'hedera-hashgraph',
#    'rank': '46',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '1053311110.9277056546983836',
#    'volumeUsd24Hr': '12900519.6528924348626470',
#    'priceUsd': '0.0710125015836137',
#    'changePercent24Hr': '0.3817556069274252',
#    'vwap24Hr': '0.0703389579288445',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'kucoin-token',
#    'rank': '47',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '98379860.9500000000000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '1046199059.5265489569889050',
#    'volumeUsd24Hr': '2358461.7724450267598338',
#    'priceUsd': '10.6342807300598137',
#    'changePercent24Hr': '-2.1250535923163214',
#    'vwap24Hr': '10.6637865097340679',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'maker',
#    'rank': '48',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '977631.0369508900000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '998345593.1118983095740580',
#    'volumeUsd24Hr': '15392533.9095011472759057',
#    'priceUsd': '1021.1885214135738183',
#    'changePercent24Hr': '-0.5421885301032788',
#    'vwap24Hr': '1025.3427760220106382',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'eos',
#    'rank': '49',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '992965777.5397000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '983541309.5596192851332889',
#    'volumeUsd24Hr': '83668892.1902409283130280',
#    'priceUsd': '0.9905087685867362',
#    'changePercent24Hr': '-1.6967570913427086',
#    'vwap24Hr': '1.0002647002821753',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'zcash',
#    'rank': '50',
#    'symbol': 'ZEC',
#    'name': 'Zcash',
#    'supply': '14697275.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '970210463.2399637809738850',
#    'volumeUsd24Hr': '47727511.3074329640758137',
#    'priceUsd': '66.0129488792965894',
#    'changePercent24Hr': '-2.7609818123020466',
#    'vwap24Hr': '65.1154114564478434',
#    'explorer': 'https://explorer.zcha.in/'},
#   {'id': 'paxos-standard',
#    'rank': '51',
#    'symbol': 'USDP',
#    'name': 'Pax Dollar',
#    'supply': '945642940.1100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '947125905.9066779331559593',
#    'volumeUsd24Hr': '26376163.2678892640346805',
#    'priceUsd': '1.0015682090287751',
#    'changePercent24Hr': '-0.0250019108833849',
#    'vwap24Hr': None,
#    'explorer': 'https://etherscan.io/token/0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#   {'id': 'aave',
#    'rank': '52',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '13899626.1929999500000000',
#    'maxSupply': '16000000.0000000000000000',
#    'marketCapUsd': '910680203.4169289309618585',
#    'volumeUsd24Hr': '48316591.2156010041023893',
#    'priceUsd': '65.5183233543043388',
#    'changePercent24Hr': '-3.5914594669126462',
#    'vwap24Hr': '66.2974029232881066',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'huobi-token',
#    'rank': '53',
#    'symbol': 'HT',
#    'name': 'Huobi Token',
#    'supply': '154409022.2544120800000000',
#    'maxSupply': '500000000.0000000000000000',
#    'marketCapUsd': '821393998.4541114425711983',
#    'volumeUsd24Hr': '11121807.4838395322860930',
#    'priceUsd': '5.3195984694517483',
#    'changePercent24Hr': '0.5229666014990801',
#    'vwap24Hr': '5.3136029134529741',
#    'explorer': 'https://etherscan.io/token/0x6f259637dcd74c767781e37bc6133cd6a68aa161'},
#   {'id': 'iota',
#    'rank': '54',
#    'symbol': 'MIOTA',
#    'name': 'IOTA',
#    'supply': '2779530283.0000000000000000',
#    'maxSupply': '2779530283.0000000000000000',
#    'marketCapUsd': '815300259.0826950153747565',
#    'volumeUsd24Hr': '5282238.9904465731115129',
#    'priceUsd': '0.2933230352154055',
#    'changePercent24Hr': '0.9636606070646499',
#    'vwap24Hr': '0.2916075218901374',
#    'explorer': 'https://thetangle.org/'},
#   {'id': 'neutrino-usd',
#    'rank': '55',
#    'symbol': 'USDN',
#    'name': 'Neutrino USD',
#    'supply': '788615575.7014000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '782146790.5456566590094769',
#    'volumeUsd24Hr': '101794.1570764194877625',
#    'priceUsd': '0.9917972896363479',
#    'changePercent24Hr': '-0.2623557401390320',
#    'vwap24Hr': '0.9891313051701148',
#    'explorer': 'https://wavesexplorer.com/'},
#   {'id': 'trustnote',
#    'rank': '56',
#    'symbol': 'TTT',
#    'name': 'TrustNote',
#    'supply': '309999945.0035280000000000',
#    'maxSupply': None,
#    'marketCapUsd': '774762222.0423094632294439',
#    'volumeUsd24Hr': '209287.5721077773119865',
#    'priceUsd': '2.4992334177139682',
#    'changePercent24Hr': '-1.0267555037552391',
#    'vwap24Hr': '2.5180131914760238',
#    'explorer': 'https://explorer.trustnote.org/'},
#   {'id': 'ecash',
#    'rank': '57',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19098967173303.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '770690661.4517673240974073',
#    'volumeUsd24Hr': '4193420.5619818335160729',
#    'priceUsd': '0.0000403524784591',
#    'changePercent24Hr': '-1.9805612057721715',
#    'vwap24Hr': '0.0000412464563997',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'the-graph',
#    'rank': '58',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '6900000000.0000000000000000',
#    'maxSupply': '10057044431.0000000000000000',
#    'marketCapUsd': '760821475.0212252900000000',
#    'volumeUsd24Hr': '20041766.9385909273546535',
#    'priceUsd': '0.1102639818871341',
#    'changePercent24Hr': '-2.3891318541973255',
#    'vwap24Hr': '0.1110917729371320',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'okb',
#    'rank': '59',
#    'symbol': 'OKB',
#    'name': 'OKB',
#    'supply': '60000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '736948661.5374222420000000',
#    'volumeUsd24Hr': '901131.5116033038837963',
#    'priceUsd': '12.2824776922903707',
#    'changePercent24Hr': '-3.4280148921832780',
#    'vwap24Hr': '12.5081121465766263',
#    'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c'},
#   {'id': 'quant',
#    'rank': '60',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14612493.0000000000000000',
#    'marketCapUsd': '723680649.6727277889126378',
#    'volumeUsd24Hr': '10168080.0124071590415874',
#    'priceUsd': '59.9433740442911781',
#    'changePercent24Hr': '-5.0551831476371719',
#    'vwap24Hr': '61.2696386632351658',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'fantom',
#    'rank': '61',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2545006273.0000000000000000',
#    'maxSupply': '3175000000.0000000000000000',
#    'marketCapUsd': '712617748.3974108917978893',
#    'volumeUsd24Hr': '73058729.0141733137928510',
#    'priceUsd': '0.2800062836612941',
#    'changePercent24Hr': '-3.1009337604513450',
#    'vwap24Hr': '0.2856396148953232',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'klaytn',
#    'rank': '62',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '2911954166.4000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '711704261.2785173066575853',
#    'volumeUsd24Hr': '9747480.6936284432684489',
#    'priceUsd': '0.2444077827496802',
#    'changePercent24Hr': '-1.1186349114781592',
#    'vwap24Hr': '0.2459231664566208',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'thorchain',
#    'rank': '63',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '330688061.3344559700000000',
#    'maxSupply': '500000000.0000000000000000',
#    'marketCapUsd': '695793102.3617089599129476',
#    'volumeUsd24Hr': '93730341.5205292026791647',
#    'priceUsd': '2.1040768739999594',
#    'changePercent24Hr': '-5.3729335456076453',
#    'vwap24Hr': '2.1612431905161993',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'neo',
#    'rank': '64',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '683771314.9752688999791952',
#    'volumeUsd24Hr': '20984157.1254615773553387',
#    'priceUsd': '9.6935447509084592',
#    'changePercent24Hr': '-0.6363161053837076',
#    'vwap24Hr': '9.7146164573006939',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'chiliz',
#    'rank': '65',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '6000378770.5472730000000000',
#    'maxSupply': '8888888888.0000000000000000',
#    'marketCapUsd': '661438296.7512285898220821',
#    'volumeUsd24Hr': '71477849.3783854275285442',
#    'priceUsd': '0.1102327573049028',
#    'changePercent24Hr': '9.5998588242561389',
#    'vwap24Hr': '0.1073080686569171',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'waves',
#    'rank': '66',
#    'symbol': 'WAVES',
#    'name': 'Waves',
#    'supply': '108643984.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '641115112.4948082257843456',
#    'volumeUsd24Hr': '99887973.1099607262608718',
#    'priceUsd': '5.9010640892440784',
#    'changePercent24Hr': '-2.9024603208605528',
#    'vwap24Hr': '6.0704212809656305',
#    'explorer': 'http://wavesexplorer.com/'},
#   {'id': 'pax-gold',
#    'rank': '67',
#    'symbol': 'PAXG',
#    'name': 'PAX Gold',
#    'supply': '333258.4930000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '610232659.3553687383118131',
#    'volumeUsd24Hr': '10331546.9441592537093345',
#    'priceUsd': '1831.1091005124623735',
#    'changePercent24Hr': '0.2227836704962063',
#    'vwap24Hr': '1831.9410804372693504',
#    'explorer': 'https://etherscan.io/token/0x45804880de22913dafe09f4980848ece6ecbaf78'},
#   {'id': 'zilliqa',
#    'rank': '68',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '12971283843.5745600000000000',
#    'maxSupply': '21000000000.0000000000000000',
#    'marketCapUsd': '585699633.2191108696864782',
#    'volumeUsd24Hr': '41768968.6647937271109578',
#    'priceUsd': '0.0451535592222232',
#    'changePercent24Hr': '-3.3175537174651395',
#    'vwap24Hr': '0.0463130215327986',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'basic-attention-token',
#    'rank': '69',
#    'symbol': 'BAT',
#    'name': 'Basic Attention Token',
#    'supply': '1497691558.0663347000000000',
#    'maxSupply': '1500000000.0000000000000000',
#    'marketCapUsd': '584894023.6669109005647414',
#    'volumeUsd24Hr': '13658183.6952399701790100',
#    'priceUsd': '0.3905303602178715',
#    'changePercent24Hr': '-3.2948232140189616',
#    'vwap24Hr': '0.3995133656585967',
#    'explorer': 'https://etherscan.io/token/Bat'},
#   {'id': 'stacks',
#    'rank': '70',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1320538205.1133470000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '583098989.7111687667320208',
#    'volumeUsd24Hr': '18329290.2251922704356814',
#    'priceUsd': '0.4415616204463536',
#    'changePercent24Hr': '6.5073914418827300',
#    'vwap24Hr': '0.4832504729845326',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'loopring',
#    'rank': '71',
#    'symbol': 'LRC',
#    'name': 'Loopring',
#    'supply': '1330088529.8379080000000000',
#    'maxSupply': '1374513896.0000000000000000',
#    'marketCapUsd': '552239894.3552027022300497',
#    'volumeUsd24Hr': '21035810.4937234762014186',
#    'priceUsd': '0.4151903290396029',
#    'changePercent24Hr': '-1.0889469088137804',
#    'vwap24Hr': '0.4159806771854218',
#    'explorer': 'https://etherscan.io/token/0xEF68e7C694F40c8202821eDF525dE3782458639f'},
#   {'id': 'dash',
#    'rank': '72',
#    'symbol': 'DASH',
#    'name': 'Dash',
#    'supply': '10794719.3779538400000000',
#    'maxSupply': '18900000.0000000000000000',
#    'marketCapUsd': '543509181.7548299367490566',
#    'volumeUsd24Hr': '39853380.8572183750248631',
#    'priceUsd': '50.3495424684076555',
#    'changePercent24Hr': '-1.4857595087381505',
#    'vwap24Hr': '50.2707201845108299',
#    'explorer': 'https://explorer.dash.org'},
#   {'id': 'enjin-coin',
#    'rank': '73',
#    'symbol': 'ENJ',
#    'name': 'Enjin Coin',
#    'supply': '895399955.5675580000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '526752925.0917025495102379',
#    'volumeUsd24Hr': '37716092.2516100933502373',
#    'priceUsd': '0.5882878615487702',
#    'changePercent24Hr': '4.1945691904193172',
#    'vwap24Hr': '0.5836719057039067',
#    'explorer': 'https://etherscan.io/token/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#   {'id': 'pancakeswap',
#    'rank': '74',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '149117952.7812237700000000',
#    'maxSupply': '750000000.0000000000000000',
#    'marketCapUsd': '501858229.4630591465003655',
#    'volumeUsd24Hr': '17871354.6817646872937635',
#    'priceUsd': '3.3655117985649463',
#    'changePercent24Hr': '0.3572875618247706',
#    'vwap24Hr': '3.3690628635372365',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'defichain',
#    'rank': '75',
#    'symbol': 'DFI',
#    'name': 'DeFiChain',
#    'supply': '510738160.8525277400000000',
#    'maxSupply': '1200000000.0000000000000000',
#    'marketCapUsd': '494477860.5808159460237720',
#    'volumeUsd24Hr': '927495.2680863259328013',
#    'priceUsd': '0.9681631381438779',
#    'changePercent24Hr': '-2.0781486237741382',
#    'vwap24Hr': '0.9885533016298347',
#    'explorer': 'http://explorer.defichain.io/'},
#   {'id': 'kusama',
#    'rank': '76',
#    'symbol': 'KSM',
#    'name': 'Kusama',
#    'supply': '8470098.0572620600000000',
#    'maxSupply': None,
#    'marketCapUsd': '452891950.9462749178430083',
#    'volumeUsd24Hr': '12628502.9859083982090858',
#    'priceUsd': '53.4695050617479173',
#    'changePercent24Hr': '-2.3746801438954846',
#    'vwap24Hr': '54.0645909546327044',
#    'explorer': 'https://kusama.subscan.io/'},
#   {'id': 'gala',
#    'rank': '77',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '6977205436.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '425704104.8558653242010720',
#    'volumeUsd24Hr': '72515913.7415838515398791',
#    'priceUsd': '0.0610135546044520',
#    'changePercent24Hr': '-1.8445488371700677',
#    'vwap24Hr': '0.0618004921663061',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'fei-protocol',
#    'rank': '78',
#    'symbol': 'FEI',
#    'name': 'Fei Protocol',
#    'supply': '424996177.7889055600000000',
#    'maxSupply': None,
#    'marketCapUsd': '425103425.1732615351998748',
#    'volumeUsd24Hr': '590871.4077548599004245',
#    'priceUsd': '1.0002523490562055',
#    'changePercent24Hr': '0.3819550269605900',
#    'vwap24Hr': '0.9917464712084805',
#    'explorer': 'https://etherscan.io/token/0x956F47F50A910163D8BF957Cf5846D573E7f87CA'},
#   {'id': 'celo',
#    'rank': '79',
#    'symbol': 'CELO',
#    'name': 'Celo',
#    'supply': '445012828.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '421524928.2335869318720972',
#    'volumeUsd24Hr': '10907481.9953848877566181',
#    'priceUsd': '0.9472197242673349',
#    'changePercent24Hr': '-0.4227191142588786',
#    'vwap24Hr': '0.9488290917541378',
#    'explorer': 'https://explorer.celo.org/blocks'},
#   {'id': 'kava',
#    'rank': '80',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '216424540.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '416770251.5527771144124900',
#    'volumeUsd24Hr': '90882529.3689255039944791',
#    'priceUsd': '1.9257069995517935',
#    'changePercent24Hr': '1.8706181735087542',
#    'vwap24Hr': '1.9225506843713126',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'curve-dao-token',
#    'rank': '81',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '537203875.0407175000000000',
#    'maxSupply': '3303030299.0000000000000000',
#    'marketCapUsd': '402479250.5788658706251627',
#    'volumeUsd24Hr': '16082392.3493810064956106',
#    'priceUsd': '0.7492113688650512',
#    'changePercent24Hr': '-3.6204581152056814',
#    'vwap24Hr': '0.7678622003118682',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'holo',
#    'rank': '82',
#    'symbol': 'HOT',
#    'name': 'Holo',
#    'supply': '173328567615.0945000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '398845247.4194087992734547',
#    'volumeUsd24Hr': '5439976.3521573910246055',
#    'priceUsd': '0.0023010935410550',
#    'changePercent24Hr': '-0.9361583802399707',
#    'vwap24Hr': '0.0023094642654127',
#    'explorer': 'https://etherscan.io/token/0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#   {'id': 'mina',
#    'rank': '83',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '563493703.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '386036215.5512193859521162',
#    'volumeUsd24Hr': '11219140.7107950907601591',
#    'priceUsd': '0.6850763600737670',
#    'changePercent24Hr': '-2.2464700973351525',
#    'vwap24Hr': '0.6945365608304341',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'amp',
#    'rank': '84',
#    'symbol': 'AMP',
#    'name': 'Amp',
#    'supply': '42227702186.0000000000000000',
#    'maxSupply': '92547638199.0000000000000000',
#    'marketCapUsd': '383094774.4004024369443230',
#    'volumeUsd24Hr': '1155693.2805472706736214',
#    'priceUsd': '0.0090721198305555',
#    'changePercent24Hr': '-2.7477692650036413',
#    'vwap24Hr': '0.0092342275469665',
#    'explorer': None},
#   {'id': 'nem',
#    'rank': '85',
#    'symbol': 'XEM',
#    'name': 'NEM',
#    'supply': '8999999999.0000000000000000',
#    'maxSupply': '8999999999.0000000000000000',
#    'marketCapUsd': '380420272.2591931808553931',
#    'volumeUsd24Hr': '4766203.7172826549260823',
#    'priceUsd': '0.0422689191446069',
#    'changePercent24Hr': '-0.6895803826258321',
#    'vwap24Hr': '0.0419394997954912',
#    'explorer': 'http://nembex.nem.ninja/'},
#   {'id': 'nexo',
#    'rank': '86',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '373932136.9168041943014227',
#    'volumeUsd24Hr': '2415773.4779763072344371',
#    'priceUsd': '0.6677359456637657',
#    'changePercent24Hr': '-5.0931163698308168',
#    'vwap24Hr': '0.6735995967461804',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': '1inch',
#    'rank': '87',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '539035948.6850792000000000',
#    'maxSupply': None,
#    'marketCapUsd': '363472565.2803182869453897',
#    'volumeUsd24Hr': '15227859.8751340733198135',
#    'priceUsd': '0.6743011596294661',
#    'changePercent24Hr': '-6.6888138456455773',
#    'vwap24Hr': '0.6980139384139503',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'compound',
#    'rank': '88',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '7156577.5747246800000000',
#    'maxSupply': '10000000.0000000000000000',
#    'marketCapUsd': '355966538.8508254434301322',
#    'volumeUsd24Hr': '24723072.2580623256653098',
#    'priceUsd': '49.7397722771865290',
#    'changePercent24Hr': '-2.6719319844977878',
#    'vwap24Hr': '51.2280579248179811',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'decred',
#    'rank': '89',
#    'symbol': 'DCR',
#    'name': 'Decred',
#    'supply': '14137160.9712833100000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '353343638.7467089018672529',
#    'volumeUsd24Hr': '387286.6556357013433508',
#    'priceUsd': '24.9939602063280392',
#    'changePercent24Hr': '-3.1622213549544019',
#    'vwap24Hr': '25.5721480351210170',
#    'explorer': 'https://mainnet.decred.org/'},
#   {'id': 'wemix',
#    'rank': '90',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '123233682.3800000000000000',
#    'maxSupply': '1015055200.0000000000000000',
#    'marketCapUsd': '347548324.0254128312398336',
#    'volumeUsd24Hr': '8786340.8582832192510647',
#    'priceUsd': '2.8202380819370662',
#    'changePercent24Hr': '-0.7042613401831906',
#    'vwap24Hr': '2.8400864159239711',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'counos-x',
#    'rank': '91',
#    'symbol': 'CCXX',
#    'name': 'Counos X',
#    'supply': '17918689.2705336400000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '340506411.1933770001754851',
#    'volumeUsd24Hr': '800531.2392026031919128',
#    'priceUsd': '19.0028637727047494',
#    'changePercent24Hr': '-0.0732369414229906',
#    'vwap24Hr': '19.5443412576464658',
#    'explorer': 'https://ccxxblocks.counos.org/'},
#   {'id': 'gatetoken',
#    'rank': '92',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '78361212.8575034300000000',
#    'maxSupply': None,
#    'marketCapUsd': '335551957.3557590199180692',
#    'volumeUsd24Hr': '3021512.1540660953710609',
#    'priceUsd': '4.2821179652482682',
#    'changePercent24Hr': '-2.0483350507601979',
#    'vwap24Hr': '4.3129378414202326',
#    'explorer': None},
#   {'id': 'xinfin-network',
#    'rank': '93',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '332266927.2456937935615841',
#    'volumeUsd24Hr': '2639101.4049925483627069',
#    'priceUsd': '0.0270283083003199',
#    'changePercent24Hr': '-6.3264356289811690',
#    'vwap24Hr': '0.0276016675030873',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'arweave',
#    'rank': '94',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '33394701.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '331544572.0393953013042440',
#    'volumeUsd24Hr': '5422631.0353361338630202',
#    'priceUsd': '9.9280593061574440',
#    'changePercent24Hr': '-3.0868642990627722',
#    'vwap24Hr': '10.0607955839970124',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'gnosis-gno',
#    'rank': '95',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2579588.0000000000000000',
#    'maxSupply': '10000000.0000000000000000',
#    'marketCapUsd': '318903906.7266761391394140',
#    'volumeUsd24Hr': '2213080.7296548877591304',
#    'priceUsd': '123.6259072094753655',
#    'changePercent24Hr': '-1.4338676915145845',
#    'vwap24Hr': '124.6256261572764840',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'symbol',
#    'rank': '96',
#    'symbol': 'XYM',
#    'name': 'Symbol',
#    'supply': '5582460004.5584020000000000',
#    'maxSupply': '8999999999.0000000000000000',
#    'marketCapUsd': '318502558.3435929037886167',
#    'volumeUsd24Hr': '758690.7126261707958734',
#    'priceUsd': '0.0570541585758818',
#    'changePercent24Hr': '2.4127295122235725',
#    'vwap24Hr': '0.0564379984233927',
#    'explorer': 'http://explorer.symbolblockchain.io/'},
#   {'id': 'qtum',
#    'rank': '97',
#    'symbol': 'QTUM',
#    'name': 'Qtum',
#    'supply': '104222595.0000000000000000',
#    'maxSupply': '107822406.0000000000000000',
#    'marketCapUsd': '314937214.0815227199567885',
#    'volumeUsd24Hr': '12090799.5762563588596072',
#    'priceUsd': '3.0217748280161583',
#    'changePercent24Hr': '0.4089893807253129',
#    'vwap24Hr': '3.0323752560030885',
#    'explorer': 'https://qtum.info/'},
#   {'id': 'storj',
#    'rank': '98',
#    'symbol': 'STORJ',
#    'name': 'Storj',
#    'supply': '397621911.9248920700000000',
#    'maxSupply': None,
#    'marketCapUsd': '311739086.3778047582122731',
#    'volumeUsd24Hr': '15766347.1379754822724716',
#    'priceUsd': '0.7840088210145975',
#    'changePercent24Hr': '-5.3956840332693284',
#    'vwap24Hr': '0.8077556270608985',
#    'explorer': 'https://etherscan.io/token/Storj'},
#   {'id': 'kadena',
#    'rank': '99',
#    'symbol': 'KDA',
#    'name': 'Kadena',
#    'supply': '184802447.9233500000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '307370018.4232230521623533',
#    'volumeUsd24Hr': '4332851.4035823040324118',
#    'priceUsd': '1.6632356436680431',
#    'changePercent24Hr': '-4.3887903379339793',
#    'vwap24Hr': '1.6741330726747995',
#    'explorer': 'https://explorer.chainweb.com/mainnet'},
#   {'id': 'bitcoin-gold',
#    'rank': '100',
#    'symbol': 'BTG',
#    'name': 'Bitcoin Gold',
#    'supply': '17513923.5890000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '304997932.6280446153508458',
#    'volumeUsd24Hr': '1314090.0332493317282736',
#    'priceUsd': '17.4145976530127829',
#    'changePercent24Hr': '0.7196940002471986',
#    'vwap24Hr': '17.4701444886474016',
#    'explorer': 'https://explorer.bitcoingold.org/insight/'}],
#  'timestamp': 1656355385126}

# %%
#lets look at the keys to understand where the data that we want lies. 

print(json_data.keys()) # we want the 'data' key
# Out:
# dict_keys(['data', 'timestamp'])

# %% [markdown]
# ### We have the json response, now we must parse through it and a csv file
#
# - We know the data we want lies within the 'data' key of the dictionary
# - We want to loop through this part of the dictionary to get the data that we want
#
# Let's say that we want the __id, name and price in USD__.

# %%
filtered_data = []
for inner_key in json_data['data']:
    listing = [inner_key['id'], inner_key['name'], inner_key['priceUsd']]
    print(listing)
# Out:
# ['bitcoin', 'Bitcoin', '20905.1583733960043616']
# ['ethereum', 'Ethereum', '1208.6113663410272691']
# ['tether', 'Tether', '1.0004246301508843']
# ['usd-coin', 'USD Coin', '1.0011880209517187']
# ['binance-coin', 'BNB', '236.4392323980789786']
# ['binance-usd', 'Binance USD', '1.0014901722240635']
# ['cardano', 'Cardano', '0.4885146366426846']
# ['xrp', 'XRP', '0.3565409513647560']
# ['solana', 'Solana', '39.0333504899463249']
# ['dogecoin', 'Dogecoin', '0.0727933115601702']
# ['polkadot', 'Polkadot', '7.8893364832979837']
# ['terra-luna', 'Terra', '2.2366220000445822']
# ['multi-collateral-dai', 'Multi Collateral DAI', '1.0009266096489814']
# ['tron', 'TRON', '0.0683610970322498']
# ['shiba-inu', 'Shiba Inu', '0.0000110925038697']
# ['avalanche', 'Avalanche', '20.0088643310624231']
# ['wrapped-bitcoin', 'Wrapped Bitcoin', '20918.9702912999770043']
# ['unus-sed-leo', 'UNUS SED LEO', '5.7968394541565198']
# ['polygon', 'Polygon', '0.5386870410413826']
# ['uniswap', 'Uniswap', '5.4237614009181014']
# ['litecoin', 'Litecoin', '56.3704731045093501']
# ['ftx-token', 'FTX Token', '27.1712983048183744']
# ['crypto-com-coin', 'Crypto.com Coin', '0.1254164873288604']
# ['chainlink', 'Chainlink', '6.6324637866021798']
# ['stellar', 'Stellar', '0.1192070508995020']
# ['near-protocol', 'NEAR Protocol', '3.7759548111071079']
# ['algorand', 'Algorand', '0.3334611005951309']
# ['ethereum-classic', 'Ethereum Classic', '16.6707207190044417']
# ['monero', 'Monero', '123.1737644651635228']
# ['bitcoin-bep2', 'Bitcoin BEP2', '20886.3570105762184279']
# ['bitcoin-cash', 'Bitcoin Cash', '112.2802620417214056']
# ['cosmos', 'Cosmos', '8.1054758643836662']
# ['vechain', 'VeChain', '0.0250045297167472']
# ['decentraland', 'Decentraland', '0.9533297079507847']
# ['flow', 'Flow', '1.6959334708889377']
# ['the-sandbox', 'The Sandbox', '1.1863173328579434']
# ['internet-computer', 'Internet Computer', '5.8374902336897061']
# ['tezos', 'Tezos', '1.5376021927851250']
# ['theta', 'THETA', '1.3486916911390895']
# ['axie-infinity', 'Axie Infinity', '16.0669253676747160']
# ['filecoin', 'Filecoin', '5.8160427885553787']
# ['helium', 'Helium', '10.7400695459017705']
# ['elrond-egld', 'Elrond', '57.4492335748504268']
# ['trueusd', 'TrueUSD', '1.0013434597793701']
# ['bitcoin-sv', 'Bitcoin SV', '60.5186596380464719']
# ['hedera-hashgraph', 'Hedera Hashgraph', '0.0710125015836137']
# ['kucoin-token', 'KuCoin Token', '10.6342807300598137']
# ['maker', 'Maker', '1021.1885214135738183']
# ['eos', 'EOS', '0.9905087685867362']
# ['zcash', 'Zcash', '66.0129488792965894']
# ['paxos-standard', 'Pax Dollar', '1.0015682090287751']
# ['aave', 'Aave', '65.5183233543043388']
# ['huobi-token', 'Huobi Token', '5.3195984694517483']
# ['iota', 'IOTA', '0.2933230352154055']
# ['neutrino-usd', 'Neutrino USD', '0.9917972896363479']
# ['trustnote', 'TrustNote', '2.4992334177139682']
# ['ecash', 'eCash', '0.0000403524784591']
# ['the-graph', 'The Graph', '0.1102639818871341']
# ['okb', 'OKB', '12.2824776922903707']
# ['quant', 'Quant', '59.9433740442911781']
# ['fantom', 'Fantom', '0.2800062836612941']
# ['klaytn', 'Klaytn', '0.2444077827496802']
# ['thorchain', 'THORChain', '2.1040768739999594']
# ['neo', 'Neo', '9.6935447509084592']
# ['chiliz', 'Chiliz', '0.1102327573049028']
# ['waves', 'Waves', '5.9010640892440784']
# ['pax-gold', 'PAX Gold', '1831.1091005124623735']
# ['zilliqa', 'Zilliqa', '0.0451535592222232']
# ['basic-attention-token', 'Basic Attention Token', '0.3905303602178715']
# ['stacks', 'Stacks', '0.4415616204463536']
# ['loopring', 'Loopring', '0.4151903290396029']
# ['dash', 'Dash', '50.3495424684076555']
# ['enjin-coin', 'Enjin Coin', '0.5882878615487702']
# ['pancakeswap', 'PancakeSwap', '3.3655117985649463']
# ['defichain', 'DeFiChain', '0.9681631381438779']
# ['kusama', 'Kusama', '53.4695050617479173']
# ['gala', 'Gala', '0.0610135546044520']
# ['fei-protocol', 'Fei Protocol', '1.0002523490562055']
# ['celo', 'Celo', '0.9472197242673349']
# ['kava', 'Kava', '1.9257069995517935']
# ['curve-dao-token', 'Curve DAO Token', '0.7492113688650512']
# ['holo', 'Holo', '0.0023010935410550']
# ['mina', 'Mina', '0.6850763600737670']
# ['amp', 'Amp', '0.0090721198305555']
# ['nem', 'NEM', '0.0422689191446069']
# ['nexo', 'Nexo', '0.6677359456637657']
# ['1inch', '1inch Network', '0.6743011596294661']
# ['compound', 'Compound', '49.7397722771865290']
# ['decred', 'Decred', '24.9939602063280392']
# ['wemix', 'WEMIX', '2.8202380819370662']
# ['counos-x', 'Counos X', '19.0028637727047494']
# ['gatetoken', 'GateToken', '4.2821179652482682']
# ['xinfin-network', 'XinFin Network', '0.0270283083003199']
# ['arweave', 'Arweave', '9.9280593061574440']
# ['gnosis-gno', 'Gnosis', '123.6259072094753655']
# ['symbol', 'Symbol', '0.0570541585758818']
# ['qtum', 'Qtum', '3.0217748280161583']
# ['storj', 'Storj', '0.7840088210145975']
# ['kadena', 'Kadena', '1.6632356436680431']
# ['bitcoin-gold', 'Bitcoin Gold', '17.4145976530127829']

# %%
filtered_data = []
for inner_key in json_data['data']:
    listing = [inner_key['id'], inner_key['name'], inner_key['priceUsd']]
    filtered_data.append(listing)

# %%
import pandas as pd

df = pd.DataFrame(filtered_data, columns = ['id', 'name', 'priceUsd'])
df.head()
# Out:
#              id      name                priceUsd
# 0       bitcoin   Bitcoin  20905.1583733960043616
# 1      ethereum  Ethereum   1208.6113663410272691
# 2        tether    Tether      1.0004246301508843
# 3      usd-coin  USD Coin      1.0011880209517187
# 4  binance-coin       BNB    236.4392323980789786

# %%
df.to_csv('CrytoPrices.csv', index = False)

# %% [markdown]
# ## Pick an API and have a play with the data yourself!
# ## This is great for getting better at data cleansing, EDA and learning how the web works. Make sure to upload your work to GitHub.
